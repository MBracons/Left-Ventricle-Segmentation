# %% [markdown]
# **<font size="6">Script para obtener un modelo capaz de segmentar el ventrículo izquierdo</font>**
#
# <dl>
# <dt>Notas:</dt>
#     <dd>- Las imágenes usadas para el entrenamiento se han obtenido usando Segment</dd>
#     <dd>- Las imágenes han sido pre-procesadas con Matlab</dd>
# </dl>

# %%
# Program: <LV_segmentation.ipynb>
# Author: Marc Bracons Cucó
# Affiliation: Department of Telecommunication and Systems Engineering, Autonomous University of Barcelona, Wireless Information Networking Group
# Copyright © 2023 Marc Bracons Cucó
# 
# This program is proprietary software; you may not use, distribute, or modify it 
# without the explicit permission of the author.
#
# If you wish to use this program in your work, please, contact the author.

# %%
#bibliotecas
import os
import csv
import pandas as pd
from PIL import Image
import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd
import tensorflow_hub as hub

# %% [markdown]
# **<font size="4">Creación de archivo CSV con toda la información que se va a necesitar</font>**

# %%
# Definir la ruta del directorio que contiene las imágenes y máscaras
base_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN"

# Definir el nombre del archivo CSV
csv_filename = "dataset.csv"

# Abrir el archivo CSV para escribir
with open(os.path.join(base_dir, csv_filename), "w") as csvfile:
    fieldnames = ["paciente", "resonancia", "mascara", "image_number"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    # Recorrer las carpetas de paciente en el directorio "original"
    for paciente_dir in os.listdir(os.path.join(base_dir, "original")):
        paciente = paciente_dir[1:] # Eliminar el guion bajo del nombre de la carpeta
        
        # Recorrer las imágenes de resonancia magnética en la carpeta del paciente
        for i, image_name in enumerate(sorted(os.listdir(os.path.join(base_dir, "original", paciente_dir)))):
            if image_name.endswith(".png"):
                image_number = i + 1
                resonancia = os.path.join(base_dir, "original", paciente_dir, image_name)
                mascara_name = f"mask_{image_name.split('_')[-1]}"
                mascara = os.path.join(base_dir, "mask", paciente_dir, mascara_name)
                
                # Escribir una fila en el archivo CSV con la información de la imagen actual
                writer.writerow({
                    "paciente": paciente,
                    "resonancia": resonancia,
                    "mascara": mascara,
                    "image_number": image_number
                })

# %%
# Cargar el archivo CSV
dataset = pd.read_csv("/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/dataset.csv")

# Imprimir la información básica del dataset
print("Información básica del dataset:")
print("Número de filas:", len(dataset))
print("Columnas:", dataset.columns)

# Imprimir las primeras 5 filas del dataset
print("\nPrimeras 5 filas del dataset:")
print(dataset.head())

# Imprimir las últimas 5 filas del dataset
print("\nÚltimas 5 filas del dataset:")
print(dataset.tail())
# Out:
# Información básica del dataset:
# Número de filas: 533
# Columnas: Index(['paciente', 'resonancia', 'mascara', 'image_number'], dtype='object')
#
# Primeras 5 filas del dataset:
#    paciente                                         resonancia  \
# 0       130  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 1       130  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 2       130  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 3       130  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 4       130  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
#
#                                              mascara  image_number
# 0  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             1
# 1  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             2
# 2  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             3
# 3  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             4
# 4  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             5
#
# Últimas 5 filas del dataset:
#      paciente                                         resonancia  \
# 528        17  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 529        17  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 530        17  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 531        17  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
# 532        17  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...
#
#                                                mascara  image_number
# 528  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             8
# 529  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...             9
# 530  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...            10
# 531  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...            11
# 532  /home/win001/00_heart/00_Dataset_CNN/02_LV_CNN...            12

# %% [markdown]
# **<font size="4">Preparación del dataset</font>**
# <dl>
#     <dt> - Se mira si todas las imágenes tienen las mismas dimensiones</dt>
#     <dt> - Se ajustan las dimensiones a (256, 256)</dt>
#     <dt> - Se verifica si se ha realizado con éxito</dt>

# %%
# Definir la ruta del directorio que contiene las imágenes de resonancia magnética
resonancia_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/original"

# Inicializar las variables para las dimensiones máximas y mínimas
max_size = (0, 0)
min_size = (float('inf'), float('inf'))

# Recorrer todas las imágenes en el directorio de resonancia magnética
for paciente_dir in os.listdir(resonancia_dir):
    for filename in os.listdir(os.path.join(resonancia_dir, paciente_dir)):
        if filename.endswith(".png"):
            # Abrir la imagen de resonancia magnética
            img = Image.open(os.path.join(resonancia_dir, paciente_dir, filename))

            # Obtener las dimensiones de la imagen
            width, height = img.size

            # Actualizar las dimensiones máximas y mínimas según corresponda
            if width * height > max_size[0] * max_size[1]:
                max_size = (width, height)
            if width * height < min_size[0] * min_size[1]:
                min_size = (width, height)

# Imprimir las dimensiones máximas y mínimas
print("Dimensión máxima de las imágenes:", max_size)
print("Dimensión mínima de las imágenes:", min_size)
# Out:
# Dimensión máxima de las imágenes: (448, 448)
# Dimensión mínima de las imágenes: (320, 320)

# %%
# Definir la ruta del directorio que contiene las imágenes de resonancia magnética y las máscaras
resonancia_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/original"
mask_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/mask"

# Definir el tamaño deseado de las imágenes
target_size = (256, 256)

# Recorrer todas las imágenes en el directorio de resonancia magnética
for paciente_dir in os.listdir(resonancia_dir):
    for filename in os.listdir(os.path.join(resonancia_dir, paciente_dir)):
        if filename.endswith(".png"):
            # Abrir la imagen de resonancia magnética
            img = Image.open(os.path.join(resonancia_dir, paciente_dir, filename))

            # Redimensionar la imagen a la resolución deseada
            resized_img = img.resize(target_size)

            # Guardar la imagen redimensionada
            resized_img.save(os.path.join(resonancia_dir, paciente_dir, filename))

            # Redimensionar la máscara correspondiente
            mask_filename = "masked_" + filename
            mask = Image.open(os.path.join(mask_dir, paciente_dir, mask_filename))
            resized_mask = mask.resize(target_size)
            resized_mask.save(os.path.join(mask_dir, paciente_dir, mask_filename))

# %%
# Definir la ruta del directorio que contiene las imágenes de resonancia magnética y las máscaras
resonancia_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/original"
mask_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/mask"

# Inicializar una variable para verificar si se encontraron imágenes con dimensiones incorrectas
found_incorrect_dimensions = False

# Recorrer todas las imágenes en el directorio de resonancia magnética
for paciente_dir in os.listdir(resonancia_dir):
    for filename in os.listdir(os.path.join(resonancia_dir, paciente_dir)):
        if filename.endswith(".png"):
            # Abrir la imagen de resonancia magnética
            img = Image.open(os.path.join(resonancia_dir, paciente_dir, filename))

            # Verificar si la imagen tiene la dimensión 256x256
            if img.size != (256, 256):
                print(f"La imagen {filename} en {paciente_dir} tiene una dimensión distinta a 256x256")
                found_incorrect_dimensions = True

            # Verificar si la máscara correspondiente tiene la dimensión 256x256
            mask_filename = "masked_" + filename
            mask = Image.open(os.path.join(mask_dir, paciente_dir, mask_filename))
            if mask.size != (256, 256):
                print(f"La máscara {mask_filename} en {paciente_dir} tiene una dimensión distinta a 256x256")
                found_incorrect_dimensions = True

# Verificar si se encontraron imágenes con dimensiones incorrectas
if not found_incorrect_dimensions:
    print("Todas las imágenes y las máscaras tienen la dimensión correcta")
# Out:
# Todas las imágenes y las máscaras tienen la dimensión correcta

# %% [markdown]
# **<font size="4">Creamos datasets de entrenamiento, testing y validación</font>**

# %%
# Definir la ruta del directorio que contiene las imágenes de resonancia magnética y las máscaras
resonancia_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/original"
mask_dir = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/mask"

# Definir el porcentaje de imágenes que se utilizarán para entrenamiento, testing y validación
train_ratio = 0.7
test_ratio = 0.2
val_ratio = 0.1

# Obtener una lista de los nombres de archivo de todas las imágenes en el directorio de resonancia magnética
all_files = []
for paciente_dir in os.listdir(resonancia_dir):
    for filename in os.listdir(os.path.join(resonancia_dir, paciente_dir)):
        if filename.endswith(".png"):
            all_files.append(os.path.join(paciente_dir, filename))

# Dividir aleatoriamente los nombres de archivo en conjuntos de entrenamiento, testing y validación
train_files, testval_files = train_test_split(all_files, test_size=(1 - train_ratio))
test_files, val_files = train_test_split(testval_files, test_size=(val_ratio / (test_ratio + val_ratio)))

# Crear un dataframe para cada conjunto de imágenes
train_df = pd.DataFrame(train_files, columns=["filename"])
test_df = pd.DataFrame(test_files, columns=["filename"])
val_df = pd.DataFrame(val_files, columns=["filename"])

# Agregar la ruta completa de cada imagen de resonancia magnética y máscara al dataframe correspondiente
for df in [train_df, test_df, val_df]:
    df["resonancia"] = resonancia_dir + "/" + df["filename"].apply(lambda x: x.split("/")[0]) + "/" + df["filename"].apply(lambda x: x.split("/")[1])
    df["mascara"] = mask_dir + "/" + df["filename"].apply(lambda x: x.split("/")[0]) + "/masked_" + df["filename"].apply(lambda x: x.split("/")[1])

# Agregar un número de imagen a cada fila de los dataframes para ayudar a ordenar las imágenes durante el entrenamiento
for df in [train_df, test_df, val_df]:
    df["image_number"] = df.index

# Guardar los dataframes en archivos CSV
train_df.to_csv("/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/train.csv", index=False)
test_df.to_csv("/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/test.csv", index=False)
val_df.to_csv("/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/val.csv", index=False)

# %% [markdown]
# **<font size="4">Entrenamiento</font>**

# %%
# Definir las rutas de los archivos CSV
train_csv = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/train.csv"
test_csv = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/test.csv"
val_csv = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/val.csv"

# Definir las dimensiones de las imágenes
img_height = 256
img_width = 256

# Definir una función para cargar las imágenes y las máscaras
def load_image(image_path, mask_path):
    # Cargar la imagen y la máscara como tensores
    image = tf.io.decode_png(tf.io.read_file(image_path), channels=1)
    mask = tf.io.decode_png(tf.io.read_file(mask_path), channels=1)
    # Normalizar los valores de los píxeles de la imagen entre 0 y 1
    image = tf.cast(image, tf.float32) / 255.0
    mask = tf.cast(mask, tf.float32) / 255.0
    # Redimensionar la imagen y la máscara
    image = tf.image.resize(image, (img_height, img_width))
    mask = tf.image.resize(mask, (img_height, img_width))
    # Devolver la imagen y la máscara como tupla
    return image, mask

# Definir una función para crear un generador de datos
def create_data_generator(csv_file, batch_size):
    # Cargar el archivo CSV en un dataframe de pandas
    df = pd.read_csv(csv_file)
    # Crear un dataset a partir del dataframe
    dataset = tf.data.Dataset.from_tensor_slices((df["resonancia"].values, df["mascara"].values))
    # Aplicar la función de carga de imágenes y máscaras al dataset
    dataset = dataset.map(load_image)
    # Mezclar y agrupar el dataset en lotes
    dataset = dataset.shuffle(buffer_size=len(df)).batch(batch_size)
    # Devolver el dataset como generador de datos
    return dataset

# Definir los hiperparámetros del modelo
batch_size = 32
epochs = 100

# Crear los generadores de datos para entrenamiento, testing y validación
train_generator = create_data_generator(train_csv, batch_size)
test_generator = create_data_generator(test_csv, batch_size)
val_generator = create_data_generator(val_csv, batch_size)

# %% [markdown]
# **<font size="4">Creación del modelo CNN basado en arquitectura U-Net</font>**

# %%
#módulo de convolución
def conv2d_block(input_tensor, n_filters, kernel_size=3):
    x = tf.keras.layers.Conv2D(n_filters, kernel_size, padding="same")(input_tensor)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(n_filters, kernel_size, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x

def encoder_block(inputs, n_filters=64, pool_size=(2, 2), dropout=0.3):
    f = conv2d_block(inputs, n_filters=n_filters)
    p = tf.keras.layers.MaxPooling2D(pool_size)(f)
    p = tf.keras.layers.Dropout(dropout)(p)
    return f, p

# %%
#codificador
input_layer = tf.keras.layers.Input(shape=(img_height, img_width, 1))

c1, p1 = encoder_block(input_layer, n_filters=64, dropout=0.1)
c2, p2 = encoder_block(p1, n_filters=128, dropout=0.1)
c3, p3 = encoder_block(p2, n_filters=256, dropout=0.1)
c4, p4 = encoder_block(p3, n_filters=512, dropout=0.1)

# %%
#decodificador
def decoder_block(inputs, conv_output, n_filters=64, kernel_size=3, strides=2, dropout=0.3):
    u = tf.keras.layers.Conv2DTranspose(n_filters, kernel_size, strides=strides, padding="same")(inputs)
    u = tf.keras.layers.Dropout(dropout)(u)
    u = tf.keras.layers.Concatenate()([u, conv_output])
    u = conv2d_block(u, n_filters)
    return u

u6 = decoder_block(p4, c4, n_filters=512, dropout=0.1)
u7 = decoder_block(u6, c3, n_filters=256, dropout=0.1)
u8 = decoder_block(u7, c2, n_filters=128, dropout=0.1)
u9 = decoder_block(u8, c1, n_filters=64, dropout=0.1)

# %%
#capa de salida
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation="sigmoid")(u9)

# %%
model = tf.keras.Model(inputs=input_layer, outputs=outputs)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['dropout[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 256)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['activation_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 512)  0           ['max_pooling2d_3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2359808    ['dropout_3[0][0]']
#  ose)
#
#  dropout_4 (Dropout)            (None, 32, 32, 512)  0           ['conv2d_transpose[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['dropout_4[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  1179904    ['activation_9[0][0]']
#  spose)
#
#  dropout_5 (Dropout)            (None, 64, 64, 256)  0           ['conv2d_transpose_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['dropout_5[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  295040     ['activation_11[0][0]']
#  spose)                         8)
#
#  dropout_6 (Dropout)            (None, 128, 128, 12  0           ['conv2d_transpose_2[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['dropout_6[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 12  512        ['conv2d_12[0][0]']
#  ormalization)                  8)
#
#  activation_12 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_12[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 12  147584      ['activation_12[0][0]']
#                                 8)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 12  512        ['conv2d_13[0][0]']
#  ormalization)                  8)
#
#  activation_13 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_13[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  73792      ['activation_13[0][0]']
#  spose)                         )
#
#  dropout_7 (Dropout)            (None, 256, 256, 64  0           ['conv2d_transpose_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['dropout_7[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  36928       ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 1)  65          ['activation_15[0][0]']
#
# ==================================================================================================
# Total params: 18,010,433
# Trainable params: 18,002,753
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# Compilar el modelo
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=["accuracy"])

# Entrenar el modelo
history = model.fit(train_generator,
                    epochs=epochs,
                    validation_data=val_generator)

# Evaluar el modelo en el conjunto de prueba
scores = model.evaluate(test_generator)
print("Loss: {:.5f}, Accuracy: {:.5f}".format(scores[0], scores[1]))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 216s 18s/step - loss: 0.5220 - accuracy: 0.7893 - val_loss: 3339.1643 - val_accuracy: 0.0138
# Epoch 2/100
# 12/12 [==============================] - 216s 18s/step - loss: 0.1752 - accuracy: 0.9891 - val_loss: 3996.5042 - val_accuracy: 0.2222
# Epoch 3/100
# 12/12 [==============================] - 215s 18s/step - loss: 0.1278 - accuracy: 0.9905 - val_loss: 50.3412 - val_accuracy: 0.2102
# Epoch 4/100
# 12/12 [==============================] - 212s 18s/step - loss: 0.1033 - accuracy: 0.9908 - val_loss: 51.4550 - val_accuracy: 0.0379
# Epoch 5/100
# 12/12 [==============================] - 211s 18s/step - loss: 0.0893 - accuracy: 0.9909 - val_loss: 24.4359 - val_accuracy: 0.0533
# Epoch 6/100
# 12/12 [==============================] - 221s 19s/step - loss: 0.0803 - accuracy: 0.9909 - val_loss: 3.1467 - val_accuracy: 0.1555
# Epoch 7/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0728 - accuracy: 0.9909 - val_loss: 1.2109 - val_accuracy: 0.3401
# Epoch 8/100
# 12/12 [==============================] - 210s 18s/step - loss: 0.0686 - accuracy: 0.9909 - val_loss: 0.6863 - val_accuracy: 0.7749
# Epoch 9/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0639 - accuracy: 0.9909 - val_loss: 1.0631 - val_accuracy: 0.5715
# Epoch 10/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0581 - accuracy: 0.9909 - val_loss: 0.2848 - val_accuracy: 0.9906
# Epoch 11/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0541 - accuracy: 0.9909 - val_loss: 0.5879 - val_accuracy: 0.7229
# Epoch 12/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0501 - accuracy: 0.9909 - val_loss: 0.0696 - val_accuracy: 0.9906
# Epoch 13/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0467 - accuracy: 0.9909 - val_loss: 0.0612 - val_accuracy: 0.9906
# Epoch 14/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0441 - accuracy: 0.9909 - val_loss: 0.1058 - val_accuracy: 0.9906
# Epoch 15/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0409 - accuracy: 0.9909 - val_loss: 0.0872 - val_accuracy: 0.9906
# Epoch 16/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0377 - accuracy: 0.9909 - val_loss: 0.0721 - val_accuracy: 0.9906
# Epoch 17/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0349 - accuracy: 0.9910 - val_loss: 0.0500 - val_accuracy: 0.9906
# Epoch 18/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0333 - accuracy: 0.9915 - val_loss: 0.1341 - val_accuracy: 0.9906
# Epoch 19/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0307 - accuracy: 0.9920 - val_loss: 0.2831 - val_accuracy: 0.9906
# Epoch 20/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0293 - accuracy: 0.9922 - val_loss: 0.4605 - val_accuracy: 0.9643
# Epoch 21/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0276 - accuracy: 0.9925 - val_loss: 0.1254 - val_accuracy: 0.9906
# Epoch 22/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0266 - accuracy: 0.9925 - val_loss: 0.3336 - val_accuracy: 0.9287
# Epoch 23/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0244 - accuracy: 0.9929 - val_loss: 0.1055 - val_accuracy: 0.9906
# Epoch 24/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.0454 - val_accuracy: 0.9906
# Epoch 25/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.0450 - val_accuracy: 0.9906
# Epoch 26/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0441 - val_accuracy: 0.9906
# Epoch 27/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 0.0450 - val_accuracy: 0.9906
# Epoch 28/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.0448 - val_accuracy: 0.9906
# Epoch 29/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.0432 - val_accuracy: 0.9906
# Epoch 30/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.0438 - val_accuracy: 0.9906
# Epoch 31/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0169 - accuracy: 0.9938 - val_loss: 0.0440 - val_accuracy: 0.9906
# Epoch 32/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0166 - accuracy: 0.9938 - val_loss: 0.0434 - val_accuracy: 0.9906
# Epoch 33/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.0451 - val_accuracy: 0.9906
# Epoch 34/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0154 - accuracy: 0.9940 - val_loss: 0.0468 - val_accuracy: 0.9906
# Epoch 35/100
# 12/12 [==============================] - 202s 17s/step - loss: 0.0146 - accuracy: 0.9942 - val_loss: 0.0441 - val_accuracy: 0.9906
# Epoch 36/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0142 - accuracy: 0.9943 - val_loss: 0.0450 - val_accuracy: 0.9906
# Epoch 37/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0141 - accuracy: 0.9941 - val_loss: 0.0453 - val_accuracy: 0.9906
# Epoch 38/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0140 - accuracy: 0.9942 - val_loss: 0.0467 - val_accuracy: 0.9906
# Epoch 39/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0133 - accuracy: 0.9944 - val_loss: 0.0445 - val_accuracy: 0.9906
# Epoch 40/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0124 - accuracy: 0.9946 - val_loss: 0.0466 - val_accuracy: 0.9906
# Epoch 41/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0124 - accuracy: 0.9945 - val_loss: 0.0465 - val_accuracy: 0.9906
# Epoch 42/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0117 - accuracy: 0.9947 - val_loss: 0.0447 - val_accuracy: 0.9906
# Epoch 43/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0124 - accuracy: 0.9943 - val_loss: 0.0447 - val_accuracy: 0.9906
# Epoch 44/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0127 - accuracy: 0.9942 - val_loss: 0.0446 - val_accuracy: 0.9907
# Epoch 45/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0115 - accuracy: 0.9946 - val_loss: 0.0328 - val_accuracy: 0.9908
# Epoch 46/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0105 - accuracy: 0.9949 - val_loss: 0.0364 - val_accuracy: 0.9911
# Epoch 47/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0107 - accuracy: 0.9948 - val_loss: 0.0389 - val_accuracy: 0.9908
# Epoch 48/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0104 - accuracy: 0.9949 - val_loss: 0.0237 - val_accuracy: 0.9910
# Epoch 49/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0102 - accuracy: 0.9950 - val_loss: 0.0289 - val_accuracy: 0.9914
# Epoch 50/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0098 - accuracy: 0.9950 - val_loss: 0.0260 - val_accuracy: 0.9918
# Epoch 51/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0096 - accuracy: 0.9950 - val_loss: 0.0244 - val_accuracy: 0.9920
# Epoch 52/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0094 - accuracy: 0.9951 - val_loss: 0.0221 - val_accuracy: 0.9924
# Epoch 53/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0094 - accuracy: 0.9951 - val_loss: 0.0136 - val_accuracy: 0.9936
# Epoch 54/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0091 - accuracy: 0.9951 - val_loss: 0.0140 - val_accuracy: 0.9939
# Epoch 55/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0086 - accuracy: 0.9953 - val_loss: 0.0169 - val_accuracy: 0.9934
# Epoch 56/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0083 - accuracy: 0.9954 - val_loss: 0.0152 - val_accuracy: 0.9936
# Epoch 57/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0085 - accuracy: 0.9953 - val_loss: 0.0184 - val_accuracy: 0.9932
# Epoch 58/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0079 - accuracy: 0.9955 - val_loss: 0.0154 - val_accuracy: 0.9938
# Epoch 59/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0077 - accuracy: 0.9955 - val_loss: 0.0181 - val_accuracy: 0.9930
# Epoch 60/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0080 - accuracy: 0.9954 - val_loss: 0.0105 - val_accuracy: 0.9944
# Epoch 61/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0076 - accuracy: 0.9955 - val_loss: 0.0102 - val_accuracy: 0.9945
# Epoch 62/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0077 - accuracy: 0.9955 - val_loss: 0.0109 - val_accuracy: 0.9944
# Epoch 63/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0073 - accuracy: 0.9956 - val_loss: 0.0105 - val_accuracy: 0.9945
# Epoch 64/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0074 - accuracy: 0.9956 - val_loss: 0.0106 - val_accuracy: 0.9943
# Epoch 65/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0072 - accuracy: 0.9956 - val_loss: 0.0122 - val_accuracy: 0.9939
# Epoch 66/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0071 - accuracy: 0.9956 - val_loss: 0.0131 - val_accuracy: 0.9939
# Epoch 67/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0073 - accuracy: 0.9956 - val_loss: 0.0112 - val_accuracy: 0.9937
# Epoch 68/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0071 - accuracy: 0.9956 - val_loss: 0.0118 - val_accuracy: 0.9942
# Epoch 69/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0067 - accuracy: 0.9958 - val_loss: 0.0099 - val_accuracy: 0.9947
# Epoch 70/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0066 - accuracy: 0.9958 - val_loss: 0.0110 - val_accuracy: 0.9941
# Epoch 71/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0073 - accuracy: 0.9955 - val_loss: 0.0101 - val_accuracy: 0.9947
# Epoch 72/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0068 - accuracy: 0.9957 - val_loss: 0.0104 - val_accuracy: 0.9945
# Epoch 73/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0062 - accuracy: 0.9959 - val_loss: 0.0085 - val_accuracy: 0.9948
# Epoch 74/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0065 - accuracy: 0.9958 - val_loss: 0.0096 - val_accuracy: 0.9947
# Epoch 75/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0060 - accuracy: 0.9960 - val_loss: 0.0115 - val_accuracy: 0.9945
# Epoch 76/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0062 - accuracy: 0.9959 - val_loss: 0.0095 - val_accuracy: 0.9948
# Epoch 77/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0060 - accuracy: 0.9959 - val_loss: 0.0118 - val_accuracy: 0.9943
# Epoch 78/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0058 - accuracy: 0.9960 - val_loss: 0.0153 - val_accuracy: 0.9938
# Epoch 79/100
# 12/12 [==============================] - 203s 17s/step - loss: 0.0057 - accuracy: 0.9960 - val_loss: 0.0095 - val_accuracy: 0.9948
# Epoch 80/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0057 - accuracy: 0.9960 - val_loss: 0.0097 - val_accuracy: 0.9946
# Epoch 81/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0053 - accuracy: 0.9962 - val_loss: 0.0124 - val_accuracy: 0.9944
# Epoch 82/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0054 - accuracy: 0.9961 - val_loss: 0.0144 - val_accuracy: 0.9939
# Epoch 83/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0055 - accuracy: 0.9961 - val_loss: 0.0115 - val_accuracy: 0.9945
# Epoch 84/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0052 - accuracy: 0.9961 - val_loss: 0.0145 - val_accuracy: 0.9941
# Epoch 85/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0051 - accuracy: 0.9962 - val_loss: 0.0125 - val_accuracy: 0.9943
# Epoch 86/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0052 - accuracy: 0.9961 - val_loss: 0.0155 - val_accuracy: 0.9937
# Epoch 87/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0052 - accuracy: 0.9962 - val_loss: 0.0096 - val_accuracy: 0.9948
# Epoch 88/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0052 - accuracy: 0.9961 - val_loss: 0.0088 - val_accuracy: 0.9949
# Epoch 89/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0050 - accuracy: 0.9962 - val_loss: 0.0111 - val_accuracy: 0.9941
# Epoch 90/100
# 12/12 [==============================] - 207s 17s/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.0096 - val_accuracy: 0.9949
# Epoch 91/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0050 - accuracy: 0.9962 - val_loss: 0.0081 - val_accuracy: 0.9950
# Epoch 92/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0050 - accuracy: 0.9962 - val_loss: 0.0121 - val_accuracy: 0.9942
# Epoch 93/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.0107 - val_accuracy: 0.9946
# Epoch 94/100
# 12/12 [==============================] - 204s 17s/step - loss: 0.0052 - accuracy: 0.9961 - val_loss: 0.0088 - val_accuracy: 0.9949
# Epoch 95/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.0101 - val_accuracy: 0.9946
# Epoch 96/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.0096 - val_accuracy: 0.9948
# Epoch 97/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0058 - accuracy: 0.9959 - val_loss: 0.0122 - val_accuracy: 0.9936
# Epoch 98/100
# 12/12 [==============================] - 202s 17s/step - loss: 0.0051 - accuracy: 0.9961 - val_loss: 0.0099 - val_accuracy: 0.9943
# Epoch 99/100
# 12/12 [==============================] - 206s 17s/step - loss: 0.0048 - accuracy: 0.9962 - val_loss: 0.0106 - val_accuracy: 0.9945
# Epoch 100/100
# 12/12 [==============================] - 205s 17s/step - loss: 0.0047 - accuracy: 0.9962 - val_loss: 0.0093 - val_accuracy: 0.9946
# 4/4 [==============================] - 14s 3s/step - loss: 0.0089 - accuracy: 0.9945
# Loss: 0.00891, Accuracy: 0.99445

# %%
model.save('/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/unet_model_100.h5')

# %% [markdown]
# **<font size="4">Pruebas con el modelo obtenido</font>**

# %%
# Cargar el modelo
model_path = '/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/unet_model_100.h5'
model = load_model(model_path)

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo previamente guardado
model = load_model('/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/unet_model_100.h5')

# Cargar la imagen de prueba
test_img_path = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/original/_14/14_7.png"
test_img = tf.io.decode_png(tf.io.read_file(test_img_path), channels=1)
test_img = tf.cast(test_img, tf.float32) / 255.0
test_img = tf.image.resize(test_img, (256, 256))

# Obtener la predicción del modelo
pred_mask = model.predict(np.array([test_img]))

# Visualizar la imagen original y la máscara predicha
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(test_img.numpy().squeeze(), cmap="gray")
axs[0].set_title("Original Image")
axs[1].imshow(pred_mask.squeeze(), cmap="gray")
axs[1].set_title("Predicted Mask")
plt.show()
# Out:
# 1/1 [==============================] - 0s 433ms/step

# %%
import pandas as pd
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo previamente guardado
model = load_model('/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/unet_model_100.h5')

# Cargar el archivo csv
csv_path = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/test.csv"
data = pd.read_csv(csv_path)

# Seleccionar la fila
row = data.iloc[72]

# Cargar la imagen de resonancia y la máscara original
resonance_img_path = row["resonancia"]
original_mask_path = row["mascara"]

resonance_img = tf.io.decode_png(tf.io.read_file(resonance_img_path), channels=1)
resonance_img = tf.cast(resonance_img, tf.float32) / 255.0
resonance_img = tf.image.resize(resonance_img, (256, 256))

original_mask = tf.io.decode_png(tf.io.read_file(original_mask_path), channels=1)
original_mask = tf.cast(original_mask, tf.float32) / 255.0
original_mask = tf.image.resize(original_mask, (256, 256))

# Obtener la predicción del modelo
pred_mask = model.predict(np.array([resonance_img]))

# Visualizar la máscara original y la máscara predicha
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(original_mask.numpy().squeeze(), cmap="gray")
axs[0].set_title("Original Mask")
axs[1].imshow(pred_mask.squeeze(), cmap="gray")
axs[1].set_title("Predicted Mask")
plt.show()
# Out:
# 1/1 [==============================] - 0s 420ms/step

# %%
import pandas as pd
from tensorflow.keras.models import load_model
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Cargar el modelo previamente guardado
model = load_model('/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/unet_model_100.h5')

# Cargar el archivo csv
csv_path = "/home/win001/00_heart/00_Dataset_CNN/02_LV_CNN/test.csv"
data = pd.read_csv(csv_path)

# Seleccionar la fila del archivo csv
row = data.iloc[72]

# Cargar la imagen de resonancia y la máscara original
resonance_img_path = row["resonancia"]
original_mask_path = row["mascara"]
filename = row["filename"]

resonance_img = tf.io.decode_png(tf.io.read_file(resonance_img_path), channels=1)
resonance_img = tf.cast(resonance_img, tf.float32) / 255.0
resonance_img = tf.image.resize(resonance_img, (256, 256))

original_mask = tf.io.decode_png(tf.io.read_file(original_mask_path), channels=1)
original_mask = tf.cast(original_mask, tf.float32) / 255.0
original_mask = tf.image.resize(original_mask, (256, 256))

# Obtener la predicción del modelo
pred_mask = model.predict(np.array([resonance_img]))

# Preparar la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 5))

# Mostrar la máscara original y la máscara predicha superpuestas
ax.imshow(original_mask.numpy().squeeze(), cmap="gray", alpha=0.5)
ax.imshow(pred_mask.squeeze(), cmap="jet", alpha=0.5)
ax.set_title(f"Original Mask (grayscale) and Predicted Mask (jet colormap) Superimposed\nFile: {filename}")

# Eliminar los ejes y mostrar la figura
ax.axis("off")
plt.show()
# Out:
# 1/1 [==============================] - 0s 433ms/step
